# %% [markdown]
# **this file is created to check duplicate text data in test.txt file and train-augmneted file.**

# %%
pwd
# Out:
# '/content'

# %%
ls
# Out:
# sample_data/  test.txt.raw  train.txt.raw

# %% [markdown]
# **if there is any common line between two files: this code will print it immidialtely.**

# %%
file1 = set(line.strip() for line in open('names.txt'))
file2 = set(line.strip() for line in open('unique-names.txt'))

for line in file1 & file2:
    if line:
        print (line)
# Out:
# Jan De Bont
# Linux LTS
# Betty White
# Martin Luther King
# Schneider
# Putin
# Chopin
# Yasser Arafat
# Andris Bērziņš
# Irving Mitchell Felt
# Carl Smith
# Brandon Lee
# Chris
# Spencer
# wolf
# Yuriko Himekusa
# Lisa Lillien
# Noriega
# Lin Piao
# Eileen Collins
# Abrams
# Guillermo Ortiz
# Barbie
# O.J. Simpson
# Susan Greene
# Sandra Maischberger
# White
# Monica Seles
# Jack Nicholson
# Dennis Brown
# Tyler Jackson
# Saburo
# Ann
# Michel Camdessus
# Hawk
# Harry Chapin
# Abraham Lincoln
# John Bower
# Ikeda
# Ruth
# Warren Harding
# Edith Piaf
# Virginia Woolf
# Ogawa
# Noriko
# Marge
# George
# Yumi
# Maria Sara
# squirrel
# Johann Wolfgang von Goethe
# Edwin Tang
# John Quincy Adams
# Peter Jackson
# Barbara
# Marie Antoinette
# Kim Tiilikainen 6:4
# Kazuko
# Andy Warhol
# Mike Tyson
# Andres Escobar
# Marzipan
# Gabi Bauer
# Watanabe
# Koko
# Charlie Chaplin
# Sarah Hale
# Liz Mohn
# Karen Elson
# Salam
# Mohammad Khalifa's
# Heather
# Ayrton Senna
# Dinosaurs
# Geiger
# ...
